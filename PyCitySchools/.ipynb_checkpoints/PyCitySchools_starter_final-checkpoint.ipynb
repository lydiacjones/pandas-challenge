# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Calculate the percentage of students who passed math **and** reading (% Overall Passing)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
tot_school = school_data["school_name"].count()
tot_student = student_data["student_name"].count()
tot_budget = school_data["budget"].sum()
avg_math = school_data_complete["math_score"].mean()
avg_read = school_data_complete["reading_score"].mean()
p_math = school_data_complete.loc[school_data_complete["math_score"] >= 70]
p_read = school_data_complete.loc[school_data_complete["reading_score"] >= 70]
percent_pass_math = (p_math["Student ID"].count())/tot_student*100
percent_pass_math
percent_pass_read = (p_read["Student ID"].count())/tot_student*100
percent_pass_math
percent_pass_read
p_overall = school_data_complete.loc[(school_data_complete["reading_score"] >= 70) &
                                    (school_data_complete["math_score"] >= 70)]
percent_pass_overall = p_overall["Student ID"].count()/tot_student*100
percent_pass_overall

summary = pd.DataFrame({"Total Schools": tot_school,
                                "Total Students": tot_student,
                                "Total Budget": '${:,.2f}'.format(tot_budget),
                                "Average Math Score": avg_math,
                                "Average Reading Score": avg_read,
                                "% Passing Math": percent_pass_math,
                                "% Passing Reading": percent_pass_read,
                                "% Overall Passing ": [percent_pass_overall]})
summary
# Out:
#    Total Schools  Total Students    Total Budget  Average Math Score  \
# 0             15           39170  $24,649,428.00           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  \
# 0               81.87784       74.980853          85.805463
#
#    % Overall Passing
# 0           65.172326

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed math **and** reading.)
#
# * Create a dataframe to hold the above results

# %%
sch_summary = school_data_complete.groupby(["school_name"])
sch_names = school_data_complete.school_name.sort_values().unique()
sch_type = sch_summary["type"].first()
sch_students = school_data_complete["school_name"].value_counts()
sch_budget = sch_summary["budget"].first()
sch_size = sch_summary["size"].first()
budg_per_stu = (sch_summary["budget"].first()) / (school_data_complete["school_name"].value_counts())
sch_avg_math = sch_summary["math_score"].mean()
sch_avg_read = sch_summary["reading_score"].mean()
sch_p_math = school_data_complete.loc[school_data_complete["math_score"] >= 70].groupby(["school_name"]).size()
sch_p_math = (sch_p_math/sch_students)*100
sch_p_read = school_data_complete.loc[school_data_complete["reading_score"] >= 70].groupby(["school_name"]).size()
sch_p_read = (sch_p_read/sch_students)*100
sch_p_overall = school_data_complete.loc[(school_data_complete["reading_score"] >= 70) &
                                    (school_data_complete["math_score"] >= 70)].groupby(["school_name"]).size()
sch_p_overall = (sch_p_overall/sch_students)*100

school_list = {
    "School Name" : sch_names,
    "School Type" : sch_type,
    "Total Students" : sch_students,
    "Total School Budget" : sch_budget,
    "Per Student Budget" : budg_per_stu,
    "Average Math Score" : sch_avg_math,
    "Average Reading Score" : sch_avg_read,
    "% Passing Math" : sch_p_math,
    "% Passing Reading" : sch_p_read,
    "% Overall Passing" : sch_p_overall
}
school_summary = pd.DataFrame(school_list)

school_summary1 = pd.DataFrame(school_list)
school_summary["Total Students"] = school_summary["Total Students"].map("{:,.0f}".format)
school_summary["Total School Budget"] = school_summary["Total School Budget"].map("${:,.2f}".format)
school_summary["Per Student Budget"] = school_summary["Per Student Budget"].map("${:,.2f}".format)



school_summary
# Out:
#                                  School Name School Type Total Students  \
# Bailey High School        Bailey High School    District          4,976
# Cabrera High School      Cabrera High School     Charter          1,858
# Figueroa High School    Figueroa High School    District          2,949
# Ford High School            Ford High School    District          2,739
# Griffin High School      Griffin High School     Charter          1,468
# Hernandez High School  Hernandez High School    District          4,635
# Holden High School        Holden High School     Charter            427
# Huang High School          Huang High School    District          2,917
# Johnson High School      Johnson High School    District          4,761
# Pena High School            Pena High School     Charter            962
# Rodriguez High School  Rodriguez High School    District          3,999
# Shelton High School      Shelton High School     Charter          1,761
# ...

# %% [markdown]
# ## Top Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the top five performing schools by % overall passing.

# %%
best_schools = school_summary.sort_values(by='% Overall Passing',ascending=False)
best_schools
# Out:
#                                  School Name School Type Total Students  \
# Cabrera High School      Cabrera High School     Charter          1,858
# Thomas High School        Thomas High School     Charter          1,635
# Griffin High School      Griffin High School     Charter          1,468
# Wilson High School        Wilson High School     Charter          2,283
# Pena High School            Pena High School     Charter            962
# Wright High School        Wright High School     Charter          1,800
# Shelton High School      Shelton High School     Charter          1,761
# Holden High School        Holden High School     Charter            427
# Bailey High School        Bailey High School    District          4,976
# Ford High School            Ford High School    District          2,739
# Johnson High School      Johnson High School    District          4,761
# Hernandez High School  Hernandez High School    District          4,635
# ...

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the five worst-performing schools by % overall passing.

# %%
worst_schools = school_summary.sort_values(by='% Overall Passing')
worst_schools
# Out:
#                                  School Name School Type Total Students  \
# Rodriguez High School  Rodriguez High School    District          3,999
# Figueroa High School    Figueroa High School    District          2,949
# Huang High School          Huang High School    District          2,917
# Hernandez High School  Hernandez High School    District          4,635
# Johnson High School      Johnson High School    District          4,761
# Ford High School            Ford High School    District          2,739
# Bailey High School        Bailey High School    District          4,976
# Holden High School        Holden High School     Charter            427
# Shelton High School      Shelton High School     Charter          1,761
# Wright High School        Wright High School     Charter          1,800
# Pena High School            Pena High School     Charter            962
# Wilson High School        Wilson High School     Charter          2,283
# ...

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
math_9th = school_data_complete[school_data_complete["grade"] == "9th"].groupby("school_name").mean()["math_score"]
math_10th = school_data_complete[school_data_complete["grade"] == "10th"].groupby("school_name").mean()["math_score"]
math_11th = school_data_complete[school_data_complete["grade"] == "11th"].groupby("school_name").mean()["math_score"]
math_12th = school_data_complete[school_data_complete["grade"] == "12th"].groupby("school_name").mean()["math_score"]

grade = {
    "Ninth Grade" : math_9th,
    "Tenth Grade" : math_10th,
    "Eleventh Grade" : math_11th,
    "Twelvth Grade" : math_12th,
}

grades_math = pd.DataFrame(grade).applymap("{:.2f}".format)
grades_math
# Out:
#                       Ninth Grade Tenth Grade Eleventh Grade Twelvth Grade
# school_name
# Bailey High School          77.08       77.00          77.52         76.49
# Cabrera High School         83.09       83.15          82.77         83.28
# Figueroa High School        76.40       76.54          76.88         77.15
# Ford High School            77.36       77.67          76.92         76.18
# Griffin High School         82.04       84.23          83.84         83.36
# Hernandez High School       77.44       77.34          77.14         77.19
# Holden High School          83.79       83.43          85.00         82.86
# Huang High School           77.03       75.91          76.45         77.23
# Johnson High School         77.19       76.69          77.49         76.86
# Pena High School            83.63       83.37          84.33         84.12
# Rodriguez High School       76.86       76.61          76.40         77.69
# ...

# %% [markdown]
# ## Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %%
read_9th = school_data_complete[school_data_complete["grade"] == "9th"].groupby("school_name").mean()["reading_score"]
read_10th = school_data_complete[school_data_complete["grade"] == "10th"].groupby("school_name").mean()["reading_score"]
read_11th = school_data_complete[school_data_complete["grade"] == "11th"].groupby("school_name").mean()["reading_score"]
read_12th = school_data_complete[school_data_complete["grade"] == "12th"].groupby("school_name").mean()["reading_score"]

grade = {
    "Ninth Grade" : read_9th,
    "Tenth Grade" : read_10th,
    "Eleventh Grade" : read_11th,
    "Twelvth Grade" : read_12th,
}

grades_read = pd.DataFrame(grade).applymap("{:.2f}".format)
grades_read
# Out:
#                       Ninth Grade Tenth Grade Eleventh Grade Twelvth Grade
# school_name
# Bailey High School          81.30       80.91          80.95         80.91
# Cabrera High School         83.68       84.25          83.79         84.29
# Figueroa High School        81.20       81.41          80.64         81.38
# Ford High School            80.63       81.26          80.40         80.66
# Griffin High School         83.37       83.71          84.29         84.01
# Hernandez High School       80.87       80.66          81.40         80.86
# Holden High School          83.68       83.32          83.82         84.70
# Huang High School           81.29       81.51          81.42         80.31
# Johnson High School         81.26       80.77          80.62         81.23
# Pena High School            83.81       83.61          84.34         84.59
# Rodriguez High School       80.99       80.63          80.86         80.38
# ...

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
bins = [0, 585, 630, 645, 680]
names = ["<$585", "$585-630", "$630-645", "$645-680"]

scores_spending = school_summary1.loc[:,['Average Math Score',
                                  'Average Reading Score','% Passing Math',
                                  '% Passing Reading','% Overall Passing',]]
scores_spending["Spending Summary"] = pd.cut(school_summary1["Per Student Budget"],bins,labels=names)
scores_by_spending = scores_spending.groupby(["Spending Summary"])
scores_by_spending.mean().applymap("{:.2f}".format)
# Out:
#                  Average Math Score Average Reading Score % Passing Math  \
# Spending Summary
# <$585                         83.46                 83.93          93.46
# $585-630                      81.90                 83.16          87.13
# $630-645                      78.52                 81.62          73.48
# $645-680                      77.00                 81.03          66.16
#
#                  % Passing Reading % Overall Passing
# Spending Summary
# <$585                        96.61             90.37
# $585-630                     92.72             81.42
# $630-645                     84.39             62.86
# $645-680                     81.13             53.53

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %%
bins = [0, 1000, 2000, 5000]
names = ["Small (<1000)", "Medium (1000-2000)", "Large (2000-5000)"]

scores_size = school_summary1.loc[:,['Average Math Score',
                                  'Average Reading Score','% Passing Math',
                                  '% Passing Reading','% Overall Passing',]]
scores_size["Total Students"] = pd.cut(school_summary1["Total Students"],bins,labels=names)
scores_by_size = scores_size.groupby(["Total Students"]).mean().applymap("{:.2f}".format)
scores_by_size
# Out:
#                    Average Math Score Average Reading Score % Passing Math  \
# Total Students
# Small (<1000)                   83.82                 83.93          93.55
# Medium (1000-2000)              83.37                 83.86          93.60
# Large (2000-5000)               77.75                 81.34          69.96
#
#                    % Passing Reading % Overall Passing
# Total Students
# Small (<1000)                  96.10             89.88
# Medium (1000-2000)             96.79             90.62
# Large (2000-5000)              82.77             58.29

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type

# %%
scores_type = school_summary.loc[:,["School Name", "School Type", 'Average Math Score',
                                  'Average Reading Score','% Passing Math',
                                  '% Passing Reading','% Overall Passing',]]
scores_by_type = scores_type.groupby("School Type").mean().applymap("{:.2f}".format)
scores_by_type
# Out:
#             Average Math Score Average Reading Score % Passing Math  \
# School Type
# Charter                  83.47                 83.90          93.62
# District                 76.96                 80.97          66.55
#
#             % Passing Reading % Overall Passing
# School Type
# Charter                 96.59             90.43
# District                80.80             53.67

# %% [markdown]
# ## Observable Trends
# * Charter schools outperformed district schools in both subjects, as well as overall.
# * Small and medium sized schools performed better than large schools.
# * Cost spent per child did not seem to have any obvious correlation with student performance.
